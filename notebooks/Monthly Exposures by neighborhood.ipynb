# %% [markdown]
# # Monthly exposures by neighborhood
# This Notebook details steps for extracting environmental exposures from Earth Engine datasets for villages/neighborhoods in the PRECISE study.

# %% [markdown]
# ## Google Colab Only section
# The below cells are only run if working in Google Colab

# %%
# Check if notebook is running in Google Colab
try:
    import google.colab
    IN_COLAB = True
except:
    IN_COLAB = False
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
if IN_COLAB:
    # Use the token from Github to clone the PRECISE repository with read/write access
    from IPython.display import clear_output; user="mlamborj"; token=input();
    # !git clone https://{user}:{token}@github.com/MSU-PALs/precisehealthgeo.git
    # Install relevant packages
    # !pip install geehydro cartopy
    # !pip install rioxarray
    # !pip install mapclassify
    clear_output()

# %% [markdown]
# ## Universal section

# %%
import os
import folium, cartopy, mapclassify
import geehydro
import geopandas as gpd
import numpy as np, pandas as pd
import cartopy.crs as ccrs
import ee
import rioxarray as rio, xarray as xr
import geemap
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from time import sleep

# %%
# Authenticate and initialise Earth Engine API
try:
    ee.Initialize(project="precise-413717")
except Exception as e:
    ee.Authenticate()
    ee.Initialize(project="precise-413717")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=AOdItlC3_7W5v4aj76QHXrWO6Xo-BjRkadID8JMUaBo&tc=oslqSbrXSQnioYplSl5dP8rPAYf5VwVs4vHxW--nuxc&cc=EXw1qj_kawoAqeeAi-wUIg6dD6ed8E0eF0mRfAproZA>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=AOdItlC3_7W5v4aj76QHXrWO6Xo-BjRkadID8JMUaBo&tc=oslqSbrXSQnioYplSl5dP8rPAYf5VwVs4vHxW--nuxc&cc=EXw1qj_kawoAqeeAi-wUIg6dD6ed8E0eF0mRfAproZA</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AVG7fiSoazJ37C7-BVePrOh9x98yVBv5lCakyu4cDL-JYYutyS1hmExxdos
# Successfully saved authorization token.

# %%
######### global variable definition #############
##################################################
# paths to geospatial datasets
path='shapefiles/precise_villages.gpkg'
path=os.path.join(r'/content/precisehealthgeo', path) if IN_COLAB else path
# analysis dates for PRECISE study
start='2018-11-01'
end='2022-12-31'
# UTM coordinate reference systems for study sites
crs_list=dict(gambia='EPSG:32628', mozambique='EPSG:32736', kenya='EPSG:32737')
# ground sampling distance (pixel size in meters) for visualization only
scale_list=dict(ndvi=dict(landsat=30, modis=1000), lst=dict(landsat=100, modis=1000, era5=11132))
extract_scale=dict(ndvi=30, lst=100) # changed this to use uniform small scale because zonal stats for big era-r pixels doesn't work
# spatial axis for xarray plotting
spatial_dims=dict(lon='x', lat='y')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Define functions
# Here we define functions to retrieve image collections and generate timeseries data by neighborhood or health facility.
#
# There is also a function for plotting results on a folium map.

# %%
def generateImageCollection(exposure, country, dataset, assign_level):

    ### image processing functions ###
    ##################################

    # load the shapefile to geodataframe
    shapefile={
        'neighborhood': f'{country}_neighborhoods',
        'facility': f'{country}_health_facilities',
        'centroid': f'{country}_centroids',
        'district': f'{country}_districts'
    }
    gdf=gpd.read_file(path, layer=shapefile[assign_level])
    # convert gdf to ee feature collection
    roi=(ee.FeatureCollection(geemap.gdf_to_ee(gdf))\
         .set('country', country))

    # generate image collection for the study period and apply functions
    if dataset=='landsat':
        # masks out clouds
        def mask_clouds(image):
            # landsat quality assesment band
            qaBand=image.select('QA_PIXEL')
            # bits 5 and 3 are cloud and cloud shadow respectively
            cloudBitMask=1<<5
            cloudShadowBitMask=1<<3
            # both bits should be equal to zero indicating clear consitions
            mask=(qaBand.bitwiseAnd(cloudBitMask).eq(0)\
                .And(qaBand.bitwiseAnd(cloudShadowBitMask).eq(0)))
            # apply the mask to the optical and thermal bands
            return (image.updateMask(mask)\
                    .select('SR_B.*', 'ST_B10')
                    .copyProperties(image, ["system:time_start"]))

        # applies landsat scaling factors
        def scale_image(image):
            opticalBands=image.select('SR_B.*').multiply(0.0000275).add(-0.2)
            thermalBand=image.select('ST_B10').multiply(0.00341802).add(149.0).subtract(273.15).rename('lst')
            return (image.addBands(opticalBands, None, True)\
                    .addBands(thermalBand, None, True))

        # computes Normalised Difference Vegetation Index
        def calculate_ndvi(image):
            ndvi=image.normalizedDifference(['SR_B5', 'SR_B4']).rename('ndvi')
            return image.addBands(ndvi)

        collection=(ee.ImageCollection('LANDSAT/LC08/C02/T1_L2')\
                    .filterBounds(roi)
                    .filterDate(start, end) #('2018-11-01', '2018-12-31') this period illustrates clouds for mozambique
                    .map(mask_clouds)
                    .map(scale_image)
                    .map(calculate_ndvi))

    elif dataset=='landsat-7':
        # masks out clouds
        def mask_clouds(image):
            # landsat quality assesment band
            qaBand=image.select('QA_PIXEL')
            # bits 5 and 3 are cloud and cloud shadow respectively
            cloudBitMask=1<<5
            cloudShadowBitMask=1<<3
            # both bits should be equal to zero indicating clear consitions
            mask=(qaBand.bitwiseAnd(cloudBitMask).eq(0)\
                .And(qaBand.bitwiseAnd(cloudShadowBitMask).eq(0)))
            # apply the mask to the optical and thermal bands
            return (image.updateMask(mask)\
                    .select('SR_B.*', 'ST_B6')
                    .copyProperties(image, ["system:time_start"]))

        # applies landsat scaling factors
        def scale_image(image):
            opticalBands=image.select('SR_B.*').multiply(0.0000275).add(-0.2)
            thermalBand=image.select('ST_B6').multiply(0.00341802).add(149.0).subtract(273.15).rename('lst')
            return (image.addBands(opticalBands, None, True)\
                    .addBands(thermalBand, None, True))

        # computes Normalised Difference Vegetation Index
        def calculate_ndvi(image):
            ndvi=image.normalizedDifference(['SR_B4', 'SR_B3']).rename('ndvi')
            return image.addBands(ndvi)

        collection=(ee.ImageCollection('LANDSAT/LE07/C02/T1_L2')\
                    .filterBounds(roi)
                    .filterDate(start, end)
                    .map(mask_clouds)
                    .map(scale_image)
                    .map(calculate_ndvi))

    elif dataset=='modis':
        # applies modis scaling factors
        def scale_image(image):
            if exposure=='ndvi':
                return (image.select('NDVI').multiply(0.0001).rename('ndvi')\
                        .copyProperties(image, ["system:time_start"]))
            else:
                return (image.select('LST_Day_1km').multiply(0.02).subtract(273.15).rename('lst')\
                        .copyProperties(image, ["system:time_start"]))
        
        collection=ee.ImageCollection("MODIS/061/MOD13Q1") if exposure=='ndvi' else ee.ImageCollection('MODIS/061/MOD11A2')
        collection=(collection.filterBounds(roi)\
                    .filterDate(start, end)
                    .map(scale_image))

    elif dataset=='era5':
        # applies era5 scaling factors
        def scale_image(image): #change ear5 to skin temperature
            return (image.select('skin_temperature').subtract(273.15).rename('lst')\
                    .copyProperties(image, ["system:time_start"]))

        collection=(ee.ImageCollection('ECMWF/ERA5_LAND/MONTHLY_AGGR')\
            # ee.ImageCollection("ECMWF/ERA5_LAND/DAILY_AGGR")\
                    .filterBounds(roi)
                    .filterDate(start, end)
                    .map(scale_image))

    return collection.select(exposure), roi
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# we can visualise our image collection on a map just to check
def drawCollection(collection, exposure, country):
    # map centres
    getCenter=dict(gambia=[13.443, -15.864], mozambique=[-25.1914, 32.7539], kenya=[-3.9995, 39.3609])
    # color palette
    viz={'ndvi': dict(min=-0.2, max=1, palette='8bc4f9, c9995c, c7d270, 8add60, 097210'), 'lst': dict(min=0, max=60, palette='6495ed, 32cd32, fdda0d, 8b4000, ff0000')}
    # Use folium to visualize the image collection
    map=folium.Map(location=getCenter[country], zoom_start=8)
    map.addLayer(collection[0], viz[exposure])
    map.addLayer(collection[1])
    return map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def generateMonthlyTimeSeries(input_collection, exposure, country, dataset, assign_level):
    """
    Function to generate a dataframe with monthly mean values by assignement level
    """
    
    assign_level='neighborhood' if assign_level=='centroid' else assign_level
    
    # get date range of image collection
    start=ee.Date(input_collection[0].aggregate_min('system:time_start'))
    end=ee.Date(input_collection[0].aggregate_max('system:time_start'))
    n_months=end.difference(start, 'months').add(1)
    months=ee.List.sequence(0, n_months.int())
    # generate unique dates for analysis period
    dates=months.map(lambda i: start.advance(i, 'month'))

    # Groups images by month and computes mean
    def monthly_agg(date, collection):
        start=ee.Date(date)
        end=ee.Date(date).advance(1, 'month')
        collection=collection.filterDate(start, end).mean() #pixel-wise mean for entire collection
        return (collection.set('system:time_start', start.millis())\
                .set('count', collection.bandNames().length())) #this helps us identify months without images

    # generate monthly mean image collection
    mean_monthly=ee.ImageCollection.fromImages(dates.map(lambda i: monthly_agg(i, input_collection[0]))\
                                                 .filter(ee.Filter.gt('count', 0)))  #retain only non-null images

    # Computes mean value for each neighborhood
    def reduceMean(image):
        features=image.reduceRegions(
            reducer=ee.Reducer.mean(),
            collection=input_collection[1],
            scale=extract_scale[exposure],
            crs=crs_list[country])
        return features.map(lambda f: f.set('exposure_month', image.date().format()))

    # Computes mean value for each health facility
    def extractPoint(image):
        features=image.sampleRegions(
            collection=input_collection[1],
            scale=extract_scale[exposure],
            geometries=True,
            projection=crs_list[country])
        return features.map(lambda f: f.set('exposure_month', image.date().format()))

    # generate monthly mean for either polygons or points
    exposures=mean_monthly.map(reduceMean) if input_collection[1].geometry().type().getInfo()[5:]=='Polygon' else mean_monthly.map(extractPoint)
    # export to dataframe and set new index
    exposures=(geemap.ee_to_df(exposures.flatten())\
               .rename(columns={'mean': exposure}))
    # change exposure month datetime format
    exposures['exposure_month']=exposures['exposure_month'].apply(lambda x: pd.to_datetime(x).strftime('%Y_%m'))
    
    for col in exposures.columns:
        if col not in [f'{assign_level}_code', 'exposure_month', exposure]:
            exposures=exposures.drop(columns=col)
            
    return (exposures.set_index([f'{assign_level}_code', 'exposure_month'])\
            .sort_index())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# def generateDailyTimeSeries(input_collection, exposure, country, dataset):
#     # get date range of image collection
#     start=ee.Date(input_collection[0].aggregate_min('system:time_start'))
#     end=ee.Date(input_collection[0].aggregate_max('system:time_start'))
#     n_months=end.difference(start, 'days').add(1)
#     months=ee.List.sequence(0, n_months.int())
#     # generate unique dates for analysis period
#     dates=months.map(lambda i: start.advance(i, 'day'))
    
#     # Computes daily mean
#     def daily_agg(date, collection):
#         start=ee.Date(date)
#         end=ee.Date(date).advance(1, 'day')
#         collection=collection.filterDate(start, end).mean() #pixel-wise mean for entire collection
#         return (collection.set('system:time_start', start.millis())\
#                 .set('count', collection.bandNames().length()))

#     # generate daily mean image collection
#     mean_daily=ee.ImageCollection.fromImages(dates.map(lambda i: daily_agg(i, input_collection[0]))\
#                                                  .filter(ee.Filter.gt('count', 0)))  #retain only non-null images

#     # Computes mean value for each neighborhood
#     def reduceMean(image):
#         features=image.reduceRegions(
#             reducer=ee.Reducer.mean(),
#             collection=input_collection[1],
#             scale=scale_list[dataset],
#             crs=crs_list[country])
#         return features.map(lambda f: f.set('exposure_month', image.date().format()))

#     # Computes mean value for each health facility
#     def extractPoint(image):
#         features=image.sampleRegions(
#             collection=input_collection[1],
#             scale=scale_list[dataset],
#             geometries=True,
#             projection=crs_list[country])
#         return features.map(lambda f: f.set('exposure_month', image.date().format()))

#     if input_collection[1].geometry().type().getInfo()[5:]=='Polygon':
#         # generate daily mean by village for image collection
#         exposures=mean_daily.map(reduceMean)
#         # export to dataframe and set new index
#         exposures=(geemap.ee_to_df(exposures.flatten())\
#                    .rename(columns={'mean': exposure})
#                    .drop(columns='name'))
#         # change exposure day datetime format
#         exposures['exposure_month']=exposures['exposure_month'].apply(lambda x: pd.to_datetime(x).strftime('%Y_%m_%d'))
#         return (exposures.set_index(['neighborhood_code', 'exposure_month'])\
#                 .sort_index())
#     else:
#         # extract daily values at facility points
#         exposures=mean_daily.map(extractPoint)
#         # export to dataframe and set new index
#         exposures=(geemap.ee_to_df(exposures.flatten())\
#                   .drop(columns=['name', 'nature']))
#         # change exposure day datetime format
#         exposures['exposure_month']=exposures['exposure_month'].apply(lambda x: pd.to_datetime(x).strftime('%Y_%m_%d'))
#         return (exposures.set_index(['facility_code', 'exposure_month'])\
#                 .sort_index())

# %%
# def aggregateTimeSeries(input_collection, exposure, country, dataset):
#     county_list=dict(gambia=['Central Baddibu', 'Upper Baddibu'], mozambique=['Manhica'], kenya=['Kilifi', 'Kwale'])
#     # utility for filtering by county
#     county_filter=[ee.Filter.eq('ADM2_NAME', county) for county in county_list[country.lower()]]
#     # get admin boundaries for country
#     counties=(ee.FeatureCollection("FAO/GAUL/2015/level2")\
#              .filter(ee.Filter.Or(*county_filter)))
     
#     # get date range of image collection
#     start=ee.Date(input_collection[0].aggregate_min('system:time_start'))
#     end=ee.Date(input_collection[0].aggregate_max('system:time_start'))
#     n_months=end.difference(start, 'months').add(1)
#     months=ee.List.sequence(0, n_months.int())
#     # generate unique dates for analysis period
#     dates=months.map(lambda i: start.advance(i, 'month'))

#     # Groups images by month and computes mean
#     def monthly_agg(date, collection):
#         start=ee.Date(date)
#         end=ee.Date(date).advance(1, 'month')
#         collection=collection.filterDate(start, end).mean() #pixel-wise mean for entire collection
#         return (collection.set('system:time_start', start.millis())\
#                 .set('count', collection.bandNames().length())) #this helps us identify months without images

#     # generate monthly mean image collection
#     mean_monthly=ee.ImageCollection.fromImages(dates.map(lambda i: monthly_agg(i, input_collection[0]))\
#                                                  .filter(ee.Filter.gt('count', 0)))  #retain only non-null images

#     # Computes mean value for entire image
#     def reduceMean(image):
#         mean=image.reduceRegion(
#             reducer=ee.Reducer.mean(),
#             geometry=counties,
#             scale=scale_list[dataset],                               
#             crs=crs_list[country]
#         ).get(exposure)
#         return image.set(exposure, mean).set('exposure_month', image.date().format())

#     # generate overall monthly mean for roi
#     exposures=(mean_monthly.map(reduceMean)\
#             .reduceColumns(ee.Reducer.toList(2), ['exposure_month', exposure]).values().get(0))
    
#     # export to dataframe and set new index
#     exposures=pd.DataFrame(exposures.getInfo(), columns=['exposure_month', exposure])
#     # change exposure month datetime format
#     exposures['exposure_month']=exposures['exposure_month'].apply(lambda x: pd.to_datetime(x).strftime('%Y_%m'))

#     return exposures.set_index('exposure_month')

# %%
def cimatologyMaps(input_collection, exposure, country, dataset):
    """
    Function to retrive image collection for entire study period. Each image is a monthly aggregate for the entire period.
    """
    county_list=dict(gambia=['Central Baddibu', 'Upper Baddibu'], mozambique=['Manhica'], kenya=['Kilifi', 'Kwale'])
    # utility for filtering by county
    county_filter=[ee.Filter.eq('ADM2_NAME', county) for county in county_list[country.lower()]]
    # get admin polygons for country and dissolve boundaries
    counties=(ee.FeatureCollection("FAO/GAUL/2015/level2")\
             .filter(ee.Filter.Or(*county_filter))
             .union(1))
    
    # get month range of a year
    months=ee.List.sequence(1, 12)
    
    def monthly_agg(m):
        return (input_collection[0].filter(ee.Filter.calendarRange(m, m, 'month'))\
                .mean()
                .set('month', m))

    # group by month and calculate monthly mean image collection
    mean_monthly=(ee.ImageCollection.fromImages(months.map(monthly_agg))\
                  .map(lambda i: i.clip(counties)))
        
    # export image to xarray
    lst_raster=geemap.ee_to_xarray(mean_monthly, crs='EPSG:4326', scale=scale_list['lst'][dataset]*0.001/111, geometry=counties.geometry())
    # remove outliers from the data
    lst_raster['lst']=xr.where((lst_raster['lst']>5) & (lst_raster['lst']<100), lst_raster['lst'], np.nan)
    # specify spatial dimensions
    lst_raster['lst']=(lst_raster['lst'].rename(**spatial_dims)\
                       # reorder axis for xarray plotting
                       .transpose('y', 'x', 'time')
                       # specify crs
                       .rio.write_crs('EPSG:4326')
                       # specify nodata value
                       .rio.write_nodata(np.nan))
    
    return lst_raster
    
    # task = ee.batch.Export.image.toDrive(
    #     image=mean_monthly.first(),
    #     description=f'{dataset}_{country}',
    #     scale=scale_list['lst'][dataset],
    #     region=counties.geometry().bounds(),
    #     maxPixels=1e10
    # )
    # return task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# def monthly_exposures(exposure, country, dataset, assign_level, draw_map=False):
#     images=generateImageCollection(exposure, country, dataset, assign_level)
#     return drawCollection(images, exposure, country) if draw_map else generateMonthlyTimeSeries(images, exposure, country, dataset, assign_level)

# %%
# def daily_exposures(exposure, country, dataset, facilities=False, draw_map=False):
#     images=generateImageCollection(exposure, country, dataset, facilities)
#     return drawCollection(images, exposure, country) if draw_map else generateDailyTimeSeries(images, exposure, country, dataset)

# %%
# def agg_monthly_exposures(exposure, country, dataset, facilities=False, draw_map=False):
#     images=generateImageCollection(exposure, country, dataset, facilities)
#     return drawCollection(images, exposure, country) if draw_map else aggregateTimeSeries(images, exposure, country, dataset)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def agg_monthly_exposure_maps(exposure, country, dataset, facilities=False, draw_map=False):
    images=generateImageCollection(exposure, country, dataset, 'neighborhood')
    return cimatologyMaps(images, exposure, country, dataset)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Generate exposures and export

# %%
countries=['gambia', 'mozambique', 'kenya']
sources=['landsat', 'modis', 'era5']
levels=['neighborhood', 'centroid', 'facility', 'district']
for country in countries:
    for level in levels:
        exposures={source: monthly_exposures('lst', country, source, level) for source in sources}
        exposures={k: df.rename(columns={'lst': k}) for k, df in exposures.items()}
        
        lst=pd.merge(exposures['landsat'], exposures['modis'], left_index=True, right_index=True, how='outer', validate='1:1')
        lst=pd.merge(lst, exposures['era5'], left_index=True, right_index=True, how='outer', validate='1:1')[sources]
        lst.to_csv(f'outputs/{country}_{level}.csv')

# %%
for country in countries:
    codes=pd.read_csv(os.path.join('shapefiles', f'{country}_neighborhood_codes.csv'))
    dffs={level:pd.read_csv(os.path.join('outputs', f'{country}_{level}.csv')) for level in levels}

    dffs['facility']=pd.merge(dffs['facility'], codes, on='facility_code', validate='m:m')
    dffs['district']=pd.merge(dffs['district'], codes, on='district_code', validate='m:m')
    
    for level, df in dffs.items():
        df['assign_level']=level
    dff=(pd.concat([df for df in dffs.values()])
         .drop(columns=['facility_code', 'district_code']))
    dff['country']=country
    dff.to_csv(os.path.join('outputs', f'{country}_combined.csv'), index=False)

# %%
# this aggregate is only used for generating figures and not analysis
landsat=agg_monthly_exposures(exposure='lst', country='kenya', dataset='landsat')
landsat7=agg_monthly_exposures(exposure='lst', country='kenya', dataset='landsat-7')
modis=agg_monthly_exposures(exposure='lst', country='kenya', dataset='modis')
era5=agg_monthly_exposures(exposure='lst', country='kenya', dataset='era5')

# %%
landsat.index=pd.to_datetime(landsat.index, format='%Y_%m')
landsat7.index=pd.to_datetime(landsat7.index, format='%Y_%m')
modis.index=pd.to_datetime(modis.index, format='%Y_%m')
era5.index=pd.to_datetime(era5.index, format='%Y_%m')

# %% [markdown]
# ## Moving from Earth Engine API to geospatial libaries
# Here we export all data we need from ee to local geos libs `geopandas` and `xarray` for ease of analysis

# %%
# def export_maps(country_name, dataset):
#     collection, roi=generateImageCollection('lst', country_name.lower(), dataset, assign_level='neighborhood')
#     # generate image mask for country
#     country=(ee.FeatureCollection("FAO/GAUL/2015/level0")\
#              .filter(ee.Filter.eq('ADM0_NAME', country_name.capitalize())))
#     # generate temporal mean and clip to country
#     collection=collection.mean().clip(country)
    
#     # define reusable parameters for exporting
#     export_params=dict(crs='EPSG:4326', scale=30*0.001/111, geometry=country.geometry())
#     county_list=dict(gambia=['Central Baddibu', 'Upper Baddibu'])
#     # utility for filtering by county
#     county_filter=[ee.Filter.eq('ADM2_NAME', county) for county in county_list[country_name.lower()]]
    
#     # export neighborhoods to geodataframe
#     neighborhoods=(geemap.ee_to_gdf(roi)\
#          .to_crs(export_params['crs']))
#     # get admin boundaries for country
#     counties=(ee.FeatureCollection("FAO/GAUL/2015/level2")\
#              .filter(ee.Filter.Or(*county_filter)))
#     # export to gdf
#     counties=(geemap.ee_to_gdf(counties)\
#               # dissolve interior boundaries
#               .dissolve(by='ADM0_NAME')
#               # match the raster crs
#               .to_crs(export_params['crs']))
    
#     # export image to xarray
#     lst_raster=geemap.ee_to_xarray(collection, **export_params)
#     # remove time dim and convert to data array
#     lst_raster=(lst_raster['lst'].isel(time=0).squeeze()\
#                 # specify nodata value
#                 .rio.write_nodata(np.nan)
#                 # specify spatial dimensions
#                 .rio.set_spatial_dims(*spatial_dims.values()))
    
#     # clip xarray to admin boundary
#     return lst_raster.rio.clip(counties.geometry, all_touched=False)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# import time
# need to delay API requests to GEE
# landsat_raster=export_maps('gambia', 'landsat')
# sleep(45)
# modis_raster=export_maps('gambia', 'modis')
# sleep(45)
# era5_raster=export_maps('gambia', 'era5')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# need to delay API requests to GEE
landsat_raster=agg_monthly_exposure_maps(exposure='lst', country='gambia', dataset='landsat')
sleep(45)
modis_raster=agg_monthly_exposure_maps(exposure='lst', country='gambia', dataset='modis')
sleep(45)
era5_raster=agg_monthly_exposure_maps(exposure='lst', country='gambia', dataset='era5')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# C:\Users\s1465450\.conda\envs\opengeo\lib\site-packages\xee\ext.py:623: UserWarning: Unable to retrieve 'system:time_start' values from an ImageCollection due to: No 'system:time_start' values found in the 'ImageCollection'.
#   warnings.warn(
# C:\Users\s1465450\.conda\envs\opengeo\lib\site-packages\xee\ext.py:623: UserWarning: Unable to retrieve 'system:time_start' values from an ImageCollection due to: No 'system:time_start' values found in the 'ImageCollection'.
#   warnings.warn(
# C:\Users\s1465450\.conda\envs\opengeo\lib\site-packages\xee\ext.py:623: UserWarning: Unable to retrieve 'system:time_start' values from an ImageCollection due to: No 'system:time_start' values found in the 'ImageCollection'.
#   warnings.warn(

# %%
# # function to sample raster values from point locations
# def extract(geom, raster):
#     return raster.sel(lon=geom.x, lat=geom.y, method='nearest').values
# facilities=gpd.read_file('shapefiles/precise_villages.gpkg', layer='gambia_health_facilities')
# facilities['landsat']=facilities['geometry'].apply(lambda x: extract(x, landsat_raster))
# facilities['modis']=facilities['geometry'].apply(lambda x: extract(x, modis_raster))
# facilities['era5']=facilities['geometry'].apply(lambda x: extract(x, era5_raster))
# voronoi=gpd.read_file('shapefiles/precise_villages.gpkg', layer='gambia_voronoi')
# join=gpd.sjoin(voronoi, facilities[['landsat', 'modis', 'era5', 'geometry']], predicate='intersects')

# %% [markdown]
# ## Assigning exposures to women
# Here we assign exposures to women at different admin levels
# 1. Assign at neighborhood level
# For this we perform a table join between neighborhood-level mean monthly lst and the pregnancy location table (neighborhood_code field)
# 2. Assign at health facility level
# For this we perform a table join between facility-level mean monthly lst and the pregnancy location table (health_facility_code field)

# %%
women=pd.read_csv('./surveillance/Gambia/pregnancy_facility_locations.csv')[['f2a_participant_id', 'exposure_month', 'village_code', 'facility_code']]
# (women.groupby(by='f2a_participant_id')
#  .agg({'f2a_participant_id': 'count'}))

# %%
neighborhoods=pd.read_csv('./outputs/gambia.csv')
neighborhood_cent=pd.read_csv('./outputs/gambia_centroids.csv')
facilities=pd.read_csv('./outputs/gambia_f.csv')

# %%
# assign neighborhood-level lst
neighb_stats=pd.merge(women, neighborhoods, left_on=['exposure_month', 'village_code'], right_on=['exposure_month', 'neighborhood_code'], how='left')
neighb_stats=neighb_stats.drop(columns=['facility_code', 'neighborhood_code'])

# %%
# neighb_stats.to_csv('outputs/gambia_women_exposures.csv')

# %%
# assign centroid-level lst
cent_stats=pd.merge(women, neighborhood_cent, left_on=['exposure_month', 'village_code'], right_on=['exposure_month', 'neighborhood_code'], how='left')
cent_stats=cent_stats.drop(columns=['facility_code', 'village_code'])

# %%
# assign facility-level lst
facility_stats=pd.merge(women, facilities, left_on=['exposure_month', 'facility_code'], right_on=['exposure_month', 'facility_code'], how='left')
facility_stats=facility_stats.drop(columns='village_code')

# %% [markdown]
# ## Generating figures
# 1. Below we generate plots to illustrate general spatial and temporal patterns of lst over the study period

# %%
ndjfmam_landsat=landsat_raster['lst'].sel(time=[10, 11, 0, 1, 2, 3, 4])
jjaso_landsat=landsat_raster['lst'].sel(time=[5, 6, 7, 8, 9])
ndjfmam_modis=modis_raster['lst'].sel(time=[10, 11, 0, 1, 2, 3, 4])
jjaso_modis=modis_raster['lst'].sel(time=[5, 6, 7, 8, 9])
ndjfmam_era5=era5_raster['lst'].sel(time=[10, 11, 0, 1, 2, 3, 4])
jjaso_era5=era5_raster['lst'].sel(time=[5, 6, 7, 8, 9])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ndjfmam_landsat
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <xarray.DataArray 'lst' (y: 232, x: 784, time: 7)>
# array([[[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
# ...
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]],
#
#        [[nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         ...,
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan],
#         [nan, nan, nan, ..., nan, nan, nan]]])
# Coordinates:
#   * time         (time) int32 10 11 0 1 2 3 4
#   * x            (x) float32 -16.01 -16.0 -16.0 -16.0 ... -15.3 -15.3 -15.3
#   * y            (y) float32 13.64 13.64 13.64 13.64 ... 13.44 13.44 13.44 13.44
#     spatial_ref  int32 0
# Attributes:
#     _FillValue:  nan

# %%
# figure 1: mean surface temperature by season 2018 to 2022
fig, axs=plt.subplots(3, 2, sharex=True, sharey=True, figsize=(7, 8))
# gridded maps
ndjfmam_landsat.mean(dim='time').plot.imshow(ax=axs[0, 0], vmin=15, vmax=50, cmap='Spectral_r', **spatial_dims)
jjaso_landsat.mean(dim='time').plot.imshow(ax=axs[0, 1], vmin=15, vmax=50, cmap='Spectral_r', **spatial_dims)
ndjfmam_modis.mean(dim='time').plot.imshow(ax=axs[1, 0], vmin=20, vmax=40, cmap='Spectral_r', **spatial_dims)
jjaso_modis.mean(dim='time').plot.imshow(ax=axs[1, 1], vmin=20, vmax=40, cmap='Spectral_r', **spatial_dims)
ndjfmam_era5.mean(dim='time').plot.imshow(ax=axs[2, 0], vmin=15, vmax=30, cmap='Spectral_r', **spatial_dims)
jjaso_era5.mean(dim='time').plot.imshow(ax=axs[2, 1], vmin=15, vmax=30, cmap='Spectral_r', **spatial_dims)
for ax in axs.flatten():
    ax.set_xlabel('')
    ax.set_ylabel('')
    ax.set_title('')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 4
#       2 fig, axs=plt.subplots(3, 2, sharex=True, sharey=True, figsize=(7, 8))
#       3 # gridded maps
# ----> 4 ndjfmam_landsat.mean(dim='time').plot.imshow(ax=axs[0, 0], vmin=15, vmax=50, cmap='Spectral_r', **spatial_dims)
#       5 jjaso_landsat.mean(dim='time').plot.imshow(ax=axs[0, 1], vmin=15, vmax=50, cmap='Spectral_r', **spatial_dims)
#       6 ndjfmam_modis.mean(dim='time').plot.imshow(ax=axs[1, 0], vmin=20, vmax=40, cmap='Spectral_r', **spatial_dims)
#
# File ~\.conda\envs\opengeo\lib\site-packages\xarray\plot\accessor.py:430, in DataArrayPlotAccessor.imshow(self, *args, **kwargs)
#     428 @functools.wraps(dataarray_plot.imshow)
#     429 def imshow(self, *args, **kwargs) -> AxesImage:
# --> 430     return dataarray_plot.imshow(self._da, *args, **kwargs)
#
# File ~\.conda\envs\opengeo\lib\site-packages\xarray\plot\dataarray_plot.py:1597, in _plot2d.<locals>.newplotfunc(***failed resolving arguments***)
#    1593     raise ValueError("plt.imshow's `aspect` kwarg is not available in xarray")
#    1595 ax = get_axis(figsize, size, aspect, ax, **subplot_kws)
# -> 1597 primitive = plotfunc(
#    1598     xplt,
#    1599     yplt,
#    1600     zval,
#    1601     ax=ax,
#    1602     cmap=cmap_params["cmap"],
#    1603     vmin=cmap_params["vmin"],
#    1604     vmax=cmap_params["vmax"],
#    1605     norm=cmap_params["norm"],
#    1606     **kwargs,
#    1607 )
#    1609 # Label the plot with metadata
#    1610 if add_labels:
#
# File ~\.conda\envs\opengeo\lib\site-packages\xarray\plot\dataarray_plot.py:1861, in imshow(x, y, z, ax, **kwargs)
#    1858         z = z.copy()
#    1859     z[np.any(z.mask, axis=-1), -1] = 0
# -> 1861 primitive = ax.imshow(z, **defaults)
#    1863 # If x or y are strings the ticklabels have been replaced with
#    1864 # integer indices. Replace them back to strings:
#    1865 for axis, v in [("x", x), ("y", y)]:
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\axes\_axes.py:5656, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5654     aspect = mpl.rcParams['image.aspect']
#    5655 self.set_aspect(aspect)
# -> 5656 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5657                       interpolation=interpolation, origin=origin,
#    5658                       extent=extent, filternorm=filternorm,
#    5659                       filterrad=filterrad, resample=resample,
#    5660                       interpolation_stage=interpolation_stage,
#    5661                       **kwargs)
#    5663 im.set_data(X)
#    5664 im.set_alpha(alpha)
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\image.py:922, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     905 @_api.make_keyword_only("3.6", name="cmap")
#     906 def __init__(self, ax,
#     907              cmap=None,
#    (...)
#     917              **kwargs
#     918              ):
#     920     self._extent = extent
# --> 922     super().__init__(
#     923         ax,
#     924         cmap=cmap,
#     925         norm=norm,
#     926         interpolation=interpolation,
#     927         origin=origin,
#     928         filternorm=filternorm,
#     929         filterrad=filterrad,
#     930         resample=resample,
#     931         interpolation_stage=interpolation_stage,
#     932         **kwargs
#     933     )
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\image.py:274, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     270 self.axes = ax
#     272 self._imcache = None
# --> 274 self._internal_update(kwargs)
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\artist.py:1223, in Artist._internal_update(self, kwargs)
#    1216 def _internal_update(self, kwargs):
#    1217     """
#    1218     Update artist properties without prenormalizing them, but generating
#    1219     errors as if calling `set`.
#    1220
#    1221     The lack of prenormalization is to maintain backcompatibility.
#    1222     """
# -> 1223     return self._update_props(
#    1224         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1225         "{prop_name!r}")
#
# File ~\.conda\envs\opengeo\lib\site-packages\matplotlib\artist.py:1197, in Artist._update_props(self, props, errfmt)
#    1195             func = getattr(self, f"set_{k}", None)
#    1196             if not callable(func):
# -> 1197                 raise AttributeError(
#    1198                     errfmt.format(cls=type(self), prop_name=k))
#    1199             ret.append(func(v))
#    1200 if ret:
#
# AttributeError: AxesImage.set() got an unexpected keyword argument 'lon'

# %%
# # figure 1: mean surface temperature gridded vs voronoi 2018 to 2022
# fig, axs=plt.subplots(3, 2, sharex=True, sharey=True, figsize=(10, 5))
# # gridded maps
# landsat_raster.plot.imshow(ax=axs[0, 0], vmin=20, vmax=60, cmap='Spectral_r', **spatial_dims)
# modis_raster.plot.imshow(ax=axs[1, 0], vmin=20, vmax=50, cmap='Spectral_r', **spatial_dims)
# era5_raster.plot.imshow(ax=axs[2, 0], vmin=20, vmax=35, cmap='Spectral_r', **spatial_dims)
# # voronoi maps
# join.plot(ax=axs[0, 1], column='landsat', cmap='YlOrRd', legend=True, aspect=1.3)
# join.plot(ax=axs[1, 1], column='modis', cmap='YlOrRd', legend=True, aspect=1.3)
# join.plot(ax=axs[2, 1], column='era5', cmap='YlOrRd', legend=True, aspect=1.3)

# for ax in axs.flatten():
#     ax.set_xlabel('')
#     ax.set_ylabel('')
#     ax.set_title('')

# %%
# figure 2: 12 month rolling mean lst gridded
fig, ax=plt.subplots(1, 1, figsize=(7, 4))
plt.plot(landsat.rolling(12).mean(), label='Landsat')
plt.plot(modis.rolling(12).mean(), label='Modis')
plt.plot(era5.rolling(12).mean(), label='Era5')
plt.ylabel('LST $(^oC)$')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=90)
plt.legend()

# %% [markdown]
# 2. Next we compare values by aggregation level, i.e. village polygon, village centroid, facility levels

# %%
# village polygons
neighborhoods=pd.read_csv(r'outputs/gambia.csv')
neighborhoods['exposure_month']=pd.to_datetime(neighborhoods['exposure_month'], format='%Y_%m')
neighborhoods=(neighborhoods.drop(columns=['neighborhood_code', 'landsat-7'])
               .rename(columns={'landsat': 'landsat_neigh', 'modis': 'modis_neigh', 'era5': 'era5_neigh'})
               .groupby(by='exposure_month')
               .agg('mean'))
# village centroids
neighborhood_cent=pd.read_csv(r'outputs/gambia_centroids.csv')
neighborhood_cent['exposure_month']=pd.to_datetime(neighborhood_cent['exposure_month'], format='%Y_%m')
neighborhood_cent=(neighborhood_cent.drop(columns=['neighborhood_code', 'landsat-7'])
               .rename(columns={'landsat': 'landsat_cent', 'modis': 'modis_cent', 'era5': 'era5_cent'})
               .groupby(by='exposure_month')
               .agg('mean'))
# health facilities
facilities=pd.read_csv(r'outputs/gambia_f.csv')
facilities['exposure_month']=pd.to_datetime(facilities['exposure_month'], format='%Y_%m')
facilities=(facilities.drop(columns=['facility_code', 'landsat-7'])
               .rename(columns={'landsat': 'landsat_facil', 'modis': 'modis_facil', 'era5': 'era5_facil'})
               .groupby(by='exposure_month')
               .agg('mean'))
# join the tables
exposures_comb=(pd.merge(neighborhoods, neighborhood_cent, left_index=True, right_index=True, validate='1:1')
               .merge(facilities, left_index=True, right_index=True, validate='1:1'))
exposures_comb

# %%
# figure 3: 12 month rolling mean lst at different agg levels
fig, axs=plt.subplots(3, 1, sharex=True, figsize=(6, 6))
axs[0].plot(exposures_comb[['landsat_neigh', 'landsat_cent', 'landsat_facil']])
axs[1].plot(exposures_comb[['modis_neigh', 'modis_cent', 'modis_facil']])
axs[2].plot(exposures_comb[['era5_neigh', 'era5_cent', 'era5_facil']])
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.xticks(rotation=90)
axs[0].set_title('Landsat')
axs[1].set_title('Modis')
axs[2].set_title('Era5')
axs[2].legend(['village-polygon', 'village-centroid', 'health-facility'])

# %%
# table values for the differences
#landsat differences
exposures_comb['landsat_neigh_cent']=exposures_comb['landsat_neigh']-exposures_comb['landsat_cent']
exposures_comb['landsat_neigh_facil']=exposures_comb['landsat_neigh']-exposures_comb['landsat_facil']
exposures_comb['landsat_facil_cent']=exposures_comb['landsat_facil']-exposures_comb['landsat_cent']
#modis differences
exposures_comb['modis_neigh_cent']=exposures_comb['modis_neigh']-exposures_comb['modis_cent']
exposures_comb['modis_neigh_facil']=exposures_comb['modis_neigh']-exposures_comb['modis_facil']
exposures_comb['modis_facil_cent']=exposures_comb['modis_facil']-exposures_comb['modis_cent']
#era5 differences
exposures_comb['era5_neigh_cent']=exposures_comb['era5_neigh']-exposures_comb['era5_cent']
exposures_comb['era5_neigh_facil']=exposures_comb['era5_neigh']-exposures_comb['era5_facil']
exposures_comb['era5_facil_cent']=exposures_comb['era5_facil']-exposures_comb['era5_cent']

exposures_comb[['landsat_neigh_cent', 'landsat_neigh_facil', 'landsat_facil_cent', 'modis_neigh_cent', 'modis_neigh_facil', 'modis_facil_cent', 'era5_neigh_cent', 'era5_neigh_facil', 'era5_facil_cent']].describe()

# %%
# figure 3: 12 month rolling mean lst at different agg levels
fig, axs=plt.subplots(3, 3, sharex=True, sharey=True, figsize=(10, 6))
#landsat differences
axs[0,0].plot(exposures_comb['landsat_neigh_cent'])
axs[0,1].plot(exposures_comb['landsat_neigh_facil'])
axs[0,2].plot(exposures_comb['landsat_facil_cent'])
#modis differences
axs[1,0].plot(exposures_comb['modis_neigh_cent'])
axs[1,1].plot(exposures_comb['modis_neigh_facil'])
axs[1,2].plot(exposures_comb['modis_facil_cent'])
#era5 differences
axs[2,0].plot(exposures_comb['era5_neigh_cent'])
axs[2,1].plot(exposures_comb['era5_neigh_facil'])
axs[2,2].plot(exposures_comb['era5_facil_cent'])
for ax in axs.flatten():
    ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    ax.tick_params('x', labelrotation=90)
# axs[0].set_title('Landsat')
# axs[1].set_title('Modis')
# axs[2].set_title('Era5')
# axs[2].legend(['village-polygon', 'village-centroid', 'health-facility'])

# %% [markdown]
# 3. Next we compare population distributions and compare sample means using statistical tests.

# %%
# figure 4: LST histograms neighborhood vs centroid vs facility level
fig, axs=plt.subplots(3, 3, sharex=True, sharey=True, figsize=(6, 5))
neighb_stats['landsat'].plot.hist(ax=axs[0, 0], bins=100, range=[20, 60])
neighb_stats['modis'].plot.hist(ax=axs[0, 1], bins=100, range=[20, 50])
neighb_stats['era5'].plot.hist(ax=axs[0, 2], bins=100, range=[20, 35])
# ax1.set_title('Landsat')
# ax2.set_title('Modis')
# ax3.set_title('Era5')
cent_stats['landsat'].plot.hist(ax=axs[1, 0], bins=100, range=[20, 60])
cent_stats['modis'].plot.hist(ax=axs[1, 1], bins=100, range=[20, 50])
cent_stats['era5'].plot.hist(ax=axs[1, 2], bins=100, range=[20, 35])
# ax1.set_title('Landsat')
# ax2.set_title('Modis')
# ax3.set_title('Era5')
facility_stats['landsat'].plot.hist(ax=axs[2, 0], bins=100, range=[20, 60])
facility_stats['modis'].plot.hist(ax=axs[2, 1], bins=100, range=[20, 50])
facility_stats['era5'].plot.hist(ax=axs[2, 2], bins=100, range=[20, 35])
# ax1.set_title('Landsat')
# ax2.set_title('Modis')
# ax3.set_title('Era5')

# %% [markdown]
# We want to see the population distribution of lst exposure by percentiles at different assignment levels. First we explore the exposure data itself to determine the percentiles.

# %%
def summarise(sample, exposures):
    cols=['landsat', 'modis', 'era5']
    # summarise df
    summary_stats=exposures.describe(percentiles=[.1, .5, .9])
    data=dict()
    # calculate percentiles
    for col in cols:
        data[col]=[]
        pc10=(sample[sample['landsat']<=summary_stats.loc['10%', col]]
             .groupby(by='f2a_participant_id')
             .agg({'f2a_participant_id': 'count'}))
        pc90=(sample[sample['landsat']>=summary_stats.loc['90%', col]]
             .groupby(by='f2a_participant_id')
             .agg({'f2a_participant_id': 'count'}))
        data[col].append(len(pc10))
        data[col].append(len(pc90))
    return data

# %%
summarise(neighb_stats, neighborhoods)

# %%
neighborhoods.describe(percentiles=[.1, .5, .9])

# %%
neighb_stats[neighb_stats['landsat']>=neighborhoods.describe(percentiles=[.1, .5, .9]).loc['90%', 'landsat']].groupby(by='f2a_participant_id').agg({'f2a_participant_id': 'count'})

# %%
gdf=gpd.read_file('./shapefiles/precise_villages.gpkg', layer='kenya_health_facilities')
gdf.explore()

# %% [markdown]
# ## Exporting rasters for figures

# %%
era5_raster['lst'].sel(time=0).plot.imshow()

# %%
# landsat_raster['lst'].sel(time=0).rio.to_raster('./outputs/landsat_gmb.tif')
# modis_raster['lst'].sel(time=0).rio.to_raster('./outputs/modis_gmb.tif')
era5_raster['lst'].sel(time=0).rio.to_raster('./outputs/era5_gmb.tif')
